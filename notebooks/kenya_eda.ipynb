# %% [markdown]
# Data Loading & Date Parsing

# %%
import pandas as pd
df = pd.read_csv('../../dataset/kenya.csv')
df.head
# Out:
# <bound method NDFrame.head of       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1     2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2     2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3     2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4     2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  19.37    25.40    15.39      10.01         2.67  81.97  2.47
# 4104  2026   87  19.66    26.40    15.24      11.16         0.59  77.40  1.98
# 4105  2026   88  19.72    26.54    14.41      12.13         0.82  77.71  1.77
# 4106  2026   89  19.68    26.81    13.86      12.95         4.59  79.29  2.01
# 4107  2026   90  19.59    25.54    15.37      10.17         1.29  80.88  2.15
#
#       WS2M_MAX     PS   QV2M
# 0         4.76  83.68   6.88
# 1         4.35  83.67   5.85
# 2         4.68  83.69   6.65
# 3         4.00  83.62   8.60
# 4         4.05  83.54   7.64
# ...        ...    ...    ...
# 4103      3.90  84.08  13.40
# 4104      3.37  84.02  12.68
# 4105      3.25  83.88  12.92
# 4106      3.32  83.87  13.16
# 4107      3.58  83.92  13.40
#
# [4108 rows x 12 columns]>

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dagic\OneDrive\Documents\KAIM\Week_0\climate-challenge-week0\.venv\Scripts\python.exe

# %%
df["Country"] = 'Kenya'
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M Country
# 0      4.76  83.68  6.88   Kenya
# 1      4.35  83.67  5.85   Kenya
# 2      4.68  83.69  6.65   Kenya
# 3      4.00  83.62  8.60   Kenya
# 4      4.05  83.54  7.64   Kenya

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"],format="%Y%j")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M Country       Date
# 0      4.76  83.68  6.88   Kenya 2015-01-01
# 1      4.35  83.67  5.85   Kenya 2015-01-02
# 2      4.68  83.69  6.65   Kenya 2015-01-03
# 3      4.00  83.62  8.60   Kenya 2015-01-04
# 4      4.05  83.54  7.64   Kenya 2015-01-05

# %%
df["Month"] = df["Date"].dt.month
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M Country       Date  Month
# 0      4.76  83.68  6.88   Kenya 2015-01-01      1
# 1      4.35  83.67  5.85   Kenya 2015-01-02      1
# 2      4.68  83.69  6.65   Kenya 2015-01-03      1
# 3      4.00  83.62  8.60   Kenya 2015-01-04      1
# 4      4.05  83.54  7.64   Kenya 2015-01-05      1

# %% [markdown]
# Summary Statistics & Missing-Value Report

# %%
import numpy as np
import pandas as pd

df = df.replace(-999, np.nan)
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M Country       Date  Month
# 0      4.76  83.68  6.88   Kenya 2015-01-01      1
# 1      4.35  83.67  5.85   Kenya 2015-01-02      1
# 2      4.68  83.69  6.65   Kenya 2015-01-03      1
# 3      4.00  83.62  8.60   Kenya 2015-01-04      1
# 4      4.05  83.54  7.64   Kenya 2015-01-05      1

# %%
dup_count = df.duplicated().sum()
print(f"Total duplicate rows found: {dup_count}")
df[df.duplicated()]

df = df.drop_duplicates()
print(f"Data shape after dropping duplicates: {df.shape}")
# Out:
# Total duplicate rows found: 0
# Data shape after dropping duplicates: (4108, 15)

# %%
numeric_summary = df.describe()
numeric_summary
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    20.427600    27.838717    14.673169
# min    2015.000000     1.000000    15.260000    18.880000     8.970000
# 25%    2017.000000    86.000000    19.460000    26.297500    13.700000
# 50%    2020.000000   179.000000    20.360000    27.875000    14.750000
# 75%    2023.000000   272.000000    21.400000    29.520000    15.750000
# max    2026.000000   366.000000    25.400000    34.270000    18.750000
# std       3.248907   106.294767     1.440824     2.358770     1.415691
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     13.165548     1.468162    65.845355     3.061765     4.375241
# min       4.110000     0.000000    28.420000     0.610000     1.160000
# 25%      11.467500     0.100000    58.677500     2.420000     3.670000
# 50%      13.260000     0.380000    66.220000     3.140000     4.430000
# 75%      15.050000     1.360000    73.280000     3.720000     5.090000
# max      20.120000    51.650000    91.070000     5.280000     7.590000
# std       2.605174     3.180228     9.934196     0.853218     0.992156
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     83.724335    11.052539  2020-08-15 12:00:00     6.423564
# min      83.310000     4.780000  2015-01-01 00:00:00     1.000000
# 25%      83.630000     9.880000  2017-10-23 18:00:00     3.000000
# 50%      83.720000    11.005000  2020-08-15 12:00:00     6.000000
# 75%      83.810000    12.350000  2023-06-08 06:00:00     9.000000
# max      84.170000    15.040000  2026-03-31 00:00:00    12.000000
# std       0.126391     1.607151                  NaN     3.477046

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# Country        0
# Date           0
# Month          0
# dtype: int64

# %%
missing_counts = df.isna().sum()

# Percentage missing
missing_percent = (missing_counts / len(df)) * 100

# Combine into a table
missing_df = pd.DataFrame({
    "Missing Values": missing_counts,
    "Percentage (%)": missing_percent
}).sort_values(by="Percentage (%)", ascending=False)

missing_df
# Out:
#              Missing Values  Percentage (%)
# YEAR                      0             0.0
# DOY                       0             0.0
# T2M                       0             0.0
# T2M_MAX                   0             0.0
# T2M_MIN                   0             0.0
# T2M_RANGE                 0             0.0
# PRECTOTCORR               0             0.0
# RH2M                      0             0.0
# WS2M                      0             0.0
# WS2M_MAX                  0             0.0
# PS                        0             0.0
# QV2M                      0             0.0
# Country                   0             0.0
# Date                      0             0.0
# Month                     0             0.0

# %% [markdown]
# Outlier Detection & Basic Cleaning

# %%
import pandas as pd
import numpy as np

cols = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

# Compute Z-scores
z_scores = (df[cols] - df[cols].mean()) / df[cols].std()

# Flag outliers
outliers = (np.abs(z_scores) > 3)

# Count rows with any outlier
outlier_rows = outliers.any(axis=1)
outlier_count = outlier_rows.sum()

print(f"Number of rows with |Z| > 3: {outlier_count}")
# Out:
# Number of rows with |Z| > 3: 120

# %%
df_capped = df.copy()

for col in cols:
    mean = df[col].mean()
    std = df[col].std()
    upper = mean + 3 * std
    lower = mean - 3 * std
    
    df_capped[col] = df[col].clip(lower, upper)

# %%
# Drop rows with >30% missing values
threshold = int(df_capped.shape[1] * 0.7)
df_clean = df_capped.dropna(thresh=threshold)

# Forward fill weather variables
df_clean[cols] = df_clean[cols].ffill()

# %%
country = "kenya"
df_clean.to_csv(f"../../dataset/{country}_clean.csv", index=False)

# %% [markdown]
# Time Series Analysis

# %%
# Convert Date column to datetime
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
# Set as index
df_clean.set_index('Date', inplace=True)

# %%
print(df_clean.index)
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2026-03-22', '2026-03-23', '2026-03-24', '2026-03-25',
#                '2026-03-26', '2026-03-27', '2026-03-28', '2026-03-29',
#                '2026-03-30', '2026-03-31'],
#               dtype='datetime64[us]', name='Date', length=4108, freq=None)

# %%
# Create monthly aggregates
monthly = df_clean.resample('ME').mean(numeric_only=True)

# Monthly precipitation (sum, not mean)
monthly_precip = df_clean.resample('ME')['PRECTOTCORR'].sum()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(monthly.index, monthly['T2M'])

# Annotate extremes
max_idx = monthly['T2M'].idxmax()
min_idx = monthly['T2M'].idxmin()

plt.scatter(max_idx, monthly.loc[max_idx,'T2M'], color='red')
plt.scatter(min_idx, monthly.loc[min_idx,'T2M'], color='blue')

plt.title("Monthly Average T2M")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# Comment: This code performs exploratory data analysis (EDA) on the Kenya climate dataset.
# It includes data cleaning steps such as handling missing values, capping outliers, and creating monthly aggregates.
# Finally, it visualizes the monthly average temperature (T2M) and highlights the maximum and minimum points.
#
# The Mpnthly average T2M plot shows the overall trend and seasonal patterns in temperature over time.
# The red point around 2019 indicates the month with the highest average temperature,
# while the blue pointaround late 2018 indicates the month with the lowest average temperature.
#
# overall this EDA reflects stable but seasonally driven temprature behaviour with requires requires detail analysis.

# %% [markdown]
# Correlation & Relationship Analysis

# %%
import seaborn as sns
numeric_df = df_clean.select_dtypes(include='number')
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Correlations:
#
#     1. WS2M vs WS2M_MAX
#         Relationship: Strong Positive
#
#         Interpretation:
#         As the average daily wind speed (WS2M) increases, the maximum gust speed (WS2M_MAX) for that day increases.
#
#     2. T2M_MAX vs T2M_RANGE
#        Relationship: Strong Positive
#
#         Interpretation:
#         Days with higher T2M_MAX has also wide T2M_RANGE.
#
#     3. RH2M vs T2M_RANGE
#        Relationship: Strong Negative
#
#         Interpretation:
#         As days RH2M increases, inversily T2M_RANGE decreases.

# %%
# T2M vs RH2M
plt.scatter(df_clean['T2M'], df_clean['RH2M'])
plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.show()

# %% [markdown]
# Relationship: This graph shows a weak positive correlation overall.
#
# Interpretation: As the temprature increases the humidity decreases.

# %%
# T2M_RANGE vs WS2M
df_clean['T2M_RANGE'] = df_clean['T2M_MAX'] - df_clean['T2M_MIN']

plt.scatter(df_clean['T2M_RANGE'], df_clean['WS2M'])
plt.xlabel('T2M_RANGE')
plt.ylabel('WS2M')
plt.show()

# %% [markdown]
# Relationship: Temprature and Wind speed has positive correlation.
#
# Interpretation: As Temprature increases wind speed also increases.

# %% [markdown]
# Distribution Analysis

# %%
plt.hist(df_clean['PRECTOTCORR'], bins=50)
plt.yscale('log')  # if skewed
plt.title("PRECTOTCORR Distribution")
plt.show()

# %% [markdown]
# Relationship: The histogram is right skewed
#
# Interpretation: The long bar at 0 indicates that most days has no rain.
#                 the right skewedness of the graph shows that light rain appear mostly than heavy rain.

# %%
plt.scatter(
    df_clean['T2M'],
    df_clean['RH2M'],
    s=df_clean['PRECTOTCORR'] * 10,  # scale bubbles
    alpha=0.5
)

plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.title('Bubble Chart')
plt.show()

# %% [markdown]
# Relationship: Negative coorelation as the bubbles slops downward.
#
# Interpretation: When temprature increases specially in between 18-20°C, there is also high humidity, which result in rain to appear.
