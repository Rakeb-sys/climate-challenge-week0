# %% [markdown]
# Data Loading & Date Parsing

# %%
import pandas as pd
df = pd.read_csv('../../dataset/nigeria.csv')
df.head
# Out:
# <bound method NDFrame.head of       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.23    29.25    22.06       7.19         0.00  68.26  1.73
# 1     2015    2  26.16    29.41    22.87       6.54         0.00  73.23  1.42
# 2     2015    3  25.66    29.02    22.63       6.39         0.00  78.71  1.69
# 3     2015    4  24.11    27.27    19.92       7.35         0.00  63.66  2.15
# 4     2015    5  23.40    27.28    18.18       9.10         0.00  59.45  1.88
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  29.05    32.43    26.69       5.74         2.82  76.60  2.35
# 4104  2026   87  28.72    31.98    27.14       4.84         5.19  79.61  2.55
# 4105  2026   88  27.72    29.53    26.21       3.32         1.43  82.83  1.10
# 4106  2026   89  28.42    31.17    26.36       4.81         0.85  77.73  2.30
# 4107  2026   90  28.40    31.73    26.32       5.41         5.33  78.79  1.76
#
#       WS2M_MAX      PS   QV2M
# 0         2.61  100.86  13.36
# 1         1.95  100.94  15.37
# 2         2.33  101.06  15.98
# 3         3.80  101.09  11.65
# 4         3.48  101.03  10.40
# ...        ...     ...    ...
# 4103      3.39  100.58  19.10
# 4104      3.17  100.64  19.49
# 4105      1.78  100.61  19.22
# 4106      3.40  100.53  18.73
# 4107      2.80  100.59  18.94
#
# [4108 rows x 12 columns]>

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dagic\OneDrive\Documents\KAIM\Week_0\climate-challenge-week0\.venv\Scripts\python.exe

# %%
df["Country"] = 'Nigeria'
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  Country
# 0      2.61  100.86  13.36  Nigeria
# 1      1.95  100.94  15.37  Nigeria
# 2      2.33  101.06  15.98  Nigeria
# 3      3.80  101.09  11.65  Nigeria
# 4      3.48  101.03  10.40  Nigeria

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"],format="%Y%j")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  Country       Date
# 0      2.61  100.86  13.36  Nigeria 2015-01-01
# 1      1.95  100.94  15.37  Nigeria 2015-01-02
# 2      2.33  101.06  15.98  Nigeria 2015-01-03
# 3      3.80  101.09  11.65  Nigeria 2015-01-04
# 4      3.48  101.03  10.40  Nigeria 2015-01-05

# %%
df["Month"] = df["Date"].dt.month
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  Country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %% [markdown]
# Summary Statistics & Missing-Value Report

# %%
import numpy as np
import pandas as pd

df = df.replace(-999, np.nan)
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.23    29.25    22.06       7.19          0.0  68.26  1.73
# 1  2015    2  26.16    29.41    22.87       6.54          0.0  73.23  1.42
# 2  2015    3  25.66    29.02    22.63       6.39          0.0  78.71  1.69
# 3  2015    4  24.11    27.27    19.92       7.35          0.0  63.66  2.15
# 4  2015    5  23.40    27.28    18.18       9.10          0.0  59.45  1.88
#
#    WS2M_MAX      PS   QV2M  Country       Date  Month
# 0      2.61  100.86  13.36  Nigeria 2015-01-01      1
# 1      1.95  100.94  15.37  Nigeria 2015-01-02      1
# 2      2.33  101.06  15.98  Nigeria 2015-01-03      1
# 3      3.80  101.09  11.65  Nigeria 2015-01-04      1
# 4      3.48  101.03  10.40  Nigeria 2015-01-05      1

# %%
dup_count = df.duplicated().sum()
print(f"Total duplicate rows found: {dup_count}")
df[df.duplicated()]

df = df.drop_duplicates()
print(f"Data shape after dropping duplicates: {df.shape}")
# Out:
# Total duplicate rows found: 0
# Data shape after dropping duplicates: (4108, 15)

# %%
numeric_summary = df.describe()
numeric_summary
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    26.656928    28.914667    24.886461
# min    2015.000000     1.000000    21.120000    25.260000    15.170000
# 25%    2017.000000    86.000000    25.720000    27.920000    24.100000
# 50%    2020.000000   179.000000    26.820000    28.990000    25.100000
# 75%    2023.000000   272.000000    27.540000    29.910000    25.860000
# max    2026.000000   366.000000    29.290000    32.880000    27.790000
# std       3.248907   106.294767     1.123335     1.294345     1.396727
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean      4.028206     4.213914    85.237040     2.217135     2.903335
# min       1.160000     0.000000    54.400000     0.740000     1.290000
# 25%       3.090000     0.330000    83.930000     1.770000     2.370000
# 50%       3.770000     1.840000    86.350000     2.200000     2.810000
# 75%       4.600000     5.200000    88.500000     2.630000     3.390000
# max      11.730000   166.100000    93.790000     4.780000     6.000000
# std       1.399169     7.266742     5.446007     0.587191     0.696885
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean    100.827205    18.558505  2020-08-15 12:00:00     6.423564
# min     100.380000     9.430000  2015-01-01 00:00:00     1.000000
# 25%     100.710000    17.970000  2017-10-23 18:00:00     3.000000
# 50%     100.820000    18.840000  2020-08-15 12:00:00     6.000000
# 75%     100.950000    19.570000  2023-06-08 06:00:00     9.000000
# max     101.350000    21.740000  2026-03-31 00:00:00    12.000000
# std       0.165321     1.646313                  NaN     3.477046

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# Country        0
# Date           0
# Month          0
# dtype: int64

# %%
missing_counts = df.isna().sum()

# Percentage missing
missing_percent = (missing_counts / len(df)) * 100

# Combine into a table
missing_df = pd.DataFrame({
    "Missing Values": missing_counts,
    "Percentage (%)": missing_percent
}).sort_values(by="Percentage (%)", ascending=False)

missing_df
# Out:
#              Missing Values  Percentage (%)
# YEAR                      0             0.0
# DOY                       0             0.0
# T2M                       0             0.0
# T2M_MAX                   0             0.0
# T2M_MIN                   0             0.0
# T2M_RANGE                 0             0.0
# PRECTOTCORR               0             0.0
# RH2M                      0             0.0
# WS2M                      0             0.0
# WS2M_MAX                  0             0.0
# PS                        0             0.0
# QV2M                      0             0.0
# Country                   0             0.0
# Date                      0             0.0
# Month                     0             0.0

# %% [markdown]
# Outlier Detection & Basic Cleaning

# %%
import pandas as pd
import numpy as np

cols = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

# Compute Z-scores
z_scores = (df[cols] - df[cols].mean()) / df[cols].std()

# Flag outliers
outliers = (np.abs(z_scores) > 3)

# Count rows with any outlier
outlier_rows = outliers.any(axis=1)
outlier_count = outlier_rows.sum()

print(f"Number of rows with |Z| > 3: {outlier_count}")
# Out:
# Number of rows with |Z| > 3: 225

# %%
df_capped = df.copy()

for col in cols:
    mean = df[col].mean()
    std = df[col].std()
    upper = mean + 3 * std
    lower = mean - 3 * std
    
    df_capped[col] = df[col].clip(lower, upper)

# %%
# Drop rows with >30% missing values
threshold = int(df_capped.shape[1] * 0.7)
df_clean = df_capped.dropna(thresh=threshold)

# Forward fill weather variables
df_clean[cols] = df_clean[cols].ffill()

# %%
country = "nigeria"
df_clean.to_csv(f"../../dataset/{country}_clean.csv", index=False)

# %% [markdown]
# Time Series Analysis

# %%
# Convert Date column to datetime
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
# Set as index
df_clean.set_index('Date', inplace=True)

# %%
print(df_clean.index)
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2026-03-22', '2026-03-23', '2026-03-24', '2026-03-25',
#                '2026-03-26', '2026-03-27', '2026-03-28', '2026-03-29',
#                '2026-03-30', '2026-03-31'],
#               dtype='datetime64[us]', name='Date', length=4108, freq=None)

# %%
# Create monthly aggregates
monthly = df_clean.resample('ME').mean(numeric_only=True)

# Monthly precipitation (sum, not mean)
monthly_precip = df_clean.resample('ME')['PRECTOTCORR'].sum()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(monthly.index, monthly['T2M'])

# Annotate extremes
max_idx = monthly['T2M'].idxmax()
min_idx = monthly['T2M'].idxmin()

plt.scatter(max_idx, monthly.loc[max_idx,'T2M'], color='red')
plt.scatter(min_idx, monthly.loc[min_idx,'T2M'], color='blue')

plt.title("Monthly Average T2M")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# Comment: This code performs exploratory data analysis (EDA) on the Nigeria climate dataset.
# It includes data cleaning steps such as handling missing values, capping outliers, and creating monthly aggregates.
# Finally, it visualizes the monthly average temperature (T2M) and highlights the maximum and minimum points.
#
# The Mpnthly average T2M plot shows the overall trend and seasonal patterns in temperature over time.
# The red point around mid 2026 indicates the month with the highest average temperature,
# while the blue pointaround late 2020 indicates the month with the lowest average temperature.
#
# overall this EDA reflects stable but seasonally driven temprature behaviour with requires requires detail analysis.

# %% [markdown]
# Correlation & Relationship Analysis

# %%
import seaborn as sns
numeric_df = df_clean.select_dtypes(include='number')
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Correlations:
#
#     1. WS2M vs WS2M_MAX
#         Relationship: Strong Positive
#
#         Interpretation:
#         As the average daily wind speed (WS2M) increases, the maximum gust speed (WS2M_MAX) for that day increases.
#
#     2. QV2M vs T2M_MIN
#        Relationship: Strong Positive
#
#         Interpretation:
#         AS QV2M increases, T2M_MIN also increases. which shows temprature fluctustion is not the only reason for RH2M increment.
#
#     3. RH2M vs T2M_RANGE
#        Relationship: Strong Negative
#
#         Interpretation:
#         As days QV2M increases, inversily T2M_RANGE decreases significantly. In this country, "stable" temperature days are likely your most humid (and possibly rainy) days, while dry days see the most extreme temperature fluctuations.

# %%
# T2M vs RH2M
plt.scatter(df_clean['T2M'], df_clean['RH2M'])
plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.show()

# %% [markdown]
# Relationship: This graph shows a weak negative correlation overall.
#
# Interpretation: As the temprature increases the humidity decreases.

# %%
# T2M_RANGE vs WS2M
df_clean['T2M_RANGE'] = df_clean['T2M_MAX'] - df_clean['T2M_MIN']

plt.scatter(df_clean['T2M_RANGE'], df_clean['WS2M'])
plt.xlabel('T2M_RANGE')
plt.ylabel('WS2M')
plt.show()

# %% [markdown]
# Relationship: Temprature and Wind speed has Negative correlation.
#
# Interpretation: As Temprature increases wind speed also decreases.

# %% [markdown]
# Distribution Analysis

# %%
plt.hist(df_clean['PRECTOTCORR'], bins=50)
plt.yscale('log')  # if skewed
plt.title("PRECTOTCORR Distribution")
plt.show()

# %% [markdown]
# Relationship: The histogram is right skewed
#
# Interpretation: The long bar at 0 indicates that most days has no rain.
#                 the right skewedness of the graph shows that light rain appear mostly than heavy rain.

# %%
plt.scatter(
    df_clean['T2M'],
    df_clean['RH2M'],
    s=df_clean['PRECTOTCORR'] * 10,  # scale bubbles
    alpha=0.5
)

plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.title('Bubble Chart')
plt.show()

# %% [markdown]
# Relationship: Negative coorelation as the bubbles slops downward.
#
# Interpretation: When temprature increases specially in between 25-28°C, there is also high humidity, which result in rain to appear.
