# %% [markdown]
# Data Loading & Date Parsing

# %%
import pandas as pd
df = pd.read_csv('../../dataset/sudan.csv')
df.head
# Out:
# <bound method NDFrame.head of       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1     2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2     2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3     2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4     2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  27.89    34.69    21.67      13.02          0.0  14.47  3.66
# 4104  2026   87  28.73    36.61    21.34      15.27          0.0   9.75  3.21
# 4105  2026   88  30.06    38.89    21.15      17.74          0.0  11.63  2.41
# 4106  2026   89  32.50    41.53    23.61      17.92          0.0  14.06  2.81
# 4107  2026   90  33.79    42.64    25.73      16.91          0.0  13.89  3.52
#
#       WS2M_MAX     PS  QV2M
# 0         5.12  96.54  6.08
# 1         5.10  96.67  4.31
# 2         6.24  96.77  6.42
# 3         6.96  96.93  3.06
# 4         5.82  96.85  2.86
# ...        ...    ...   ...
# 4103      5.11  96.47  3.52
# 4104      4.40  96.35  2.44
# 4105      3.87  96.10  3.12
# 4106      4.87  95.93  4.18
# 4107      5.00  95.89  4.47
#
# [4108 rows x 12 columns]>

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dagic\OneDrive\Documents\KAIM\Week_0\climate-challenge-week0\.venv\Scripts\python.exe

# %%
df["Country"] = 'Sudan'
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M Country
# 0      5.12  96.54  6.08   Sudan
# 1      5.10  96.67  4.31   Sudan
# 2      6.24  96.77  6.42   Sudan
# 3      6.96  96.93  3.06   Sudan
# 4      5.82  96.85  2.86   Sudan

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"],format="%Y%j")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M Country       Date
# 0      5.12  96.54  6.08   Sudan 2015-01-01
# 1      5.10  96.67  4.31   Sudan 2015-01-02
# 2      6.24  96.77  6.42   Sudan 2015-01-03
# 3      6.96  96.93  3.06   Sudan 2015-01-04
# 4      5.82  96.85  2.86   Sudan 2015-01-05

# %%
df["Month"] = df["Date"].dt.month
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M Country       Date  Month
# 0      5.12  96.54  6.08   Sudan 2015-01-01      1
# 1      5.10  96.67  4.31   Sudan 2015-01-02      1
# 2      6.24  96.77  6.42   Sudan 2015-01-03      1
# 3      6.96  96.93  3.06   Sudan 2015-01-04      1
# 4      5.82  96.85  2.86   Sudan 2015-01-05      1

# %% [markdown]
# Summary Statistics & Missing-Value Report

# %%
import numpy as np
import pandas as pd

df = df.replace(-999, np.nan)
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  25.18    35.55    16.14      19.41          0.0  31.87  3.46
# 1  2015    2  23.92    34.14    15.81      18.33          0.0  23.83  4.24
# 2  2015    3  22.73    31.64    15.09      16.55          0.0  38.21  5.01
# 3  2015    4  19.15    27.35    12.88      14.47          0.0  21.07  5.72
# 4  2015    5  17.54    27.22     9.49      17.73          0.0  21.58  4.28
#
#    WS2M_MAX     PS  QV2M Country       Date  Month
# 0      5.12  96.54  6.08   Sudan 2015-01-01      1
# 1      5.10  96.67  4.31   Sudan 2015-01-02      1
# 2      6.24  96.77  6.42   Sudan 2015-01-03      1
# 3      6.96  96.93  3.06   Sudan 2015-01-04      1
# 4      5.82  96.85  2.86   Sudan 2015-01-05      1

# %%
dup_count = df.duplicated().sum()
print(f"Total duplicate rows found: {dup_count}")
df[df.duplicated()]

df = df.drop_duplicates()
print(f"Data shape after dropping duplicates: {df.shape}")
# Out:
# Total duplicate rows found: 0
# Data shape after dropping duplicates: (4108, 15)

# %%
numeric_summary = df.describe()
numeric_summary
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    28.759007    36.773914    21.508510
# min    2015.000000     1.000000    13.180000    21.040000     5.930000
# 25%    2017.000000    86.000000    25.560000    33.730000    17.497500
# 50%    2020.000000   179.000000    29.160000    37.020000    22.890000
# 75%    2023.000000   272.000000    32.510000    40.330000    25.430000
# max    2026.000000   366.000000    37.990000    45.960000    32.170000
# std       3.248907   106.294767     4.681305     4.400065     5.091142
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     15.265404     0.643875    31.359192     3.484253     5.157378
# min       3.420000     0.000000     4.690000     0.610000     1.030000
# 25%      13.280000     0.000000    17.407500     2.730000     4.267500
# 50%      15.810000     0.000000    26.630000     3.490000     5.120000
# 75%      17.680000     0.010000    40.535000     4.220000     6.020000
# max      22.480000    66.490000    87.160000     7.150000     9.050000
# std       3.298919     3.057672    17.851849     1.040667     1.280238
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     96.346273     7.864557  2020-08-15 12:00:00     6.423564
# min      95.660000     1.160000  2015-01-01 00:00:00     1.000000
# 25%      96.160000     3.730000  2017-10-23 18:00:00     3.000000
# 50%      96.310000     5.895000  2020-08-15 12:00:00     6.000000
# 75%      96.510000    12.500000  2023-06-08 06:00:00     9.000000
# max      97.310000    19.440000  2026-03-31 00:00:00    12.000000
# std       0.266927     4.880934                  NaN     3.477046

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# Country        0
# Date           0
# Month          0
# dtype: int64

# %%
missing_counts = df.isna().sum()

# Percentage missing
missing_percent = (missing_counts / len(df)) * 100

# Combine into a table
missing_df = pd.DataFrame({
    "Missing Values": missing_counts,
    "Percentage (%)": missing_percent
}).sort_values(by="Percentage (%)", ascending=False)

missing_df
# Out:
#              Missing Values  Percentage (%)
# YEAR                      0             0.0
# DOY                       0             0.0
# T2M                       0             0.0
# T2M_MAX                   0             0.0
# T2M_MIN                   0             0.0
# T2M_RANGE                 0             0.0
# PRECTOTCORR               0             0.0
# RH2M                      0             0.0
# WS2M                      0             0.0
# WS2M_MAX                  0             0.0
# PS                        0             0.0
# QV2M                      0             0.0
# Country                   0             0.0
# Date                      0             0.0
# Month                     0             0.0

# %% [markdown]
# Outlier Detection & Basic Cleaning

# %%
import pandas as pd
import numpy as np

cols = ['T2M', 'T2M_MAX', 'T2M_MIN', 'PRECTOTCORR', 'RH2M', 'WS2M', 'WS2M_MAX']

# Compute Z-scores
z_scores = (df[cols] - df[cols].mean()) / df[cols].std()

# Flag outliers
outliers = (np.abs(z_scores) > 3)

# Count rows with any outlier
outlier_rows = outliers.any(axis=1)
outlier_count = outlier_rows.sum()

print(f"Number of rows with |Z| > 3: {outlier_count}")
# Out:
# Number of rows with |Z| > 3: 84

# %%
df_capped = df.copy()

for col in cols:
    mean = df[col].mean()
    std = df[col].std()
    upper = mean + 3 * std
    lower = mean - 3 * std
    
    df_capped[col] = df[col].clip(lower, upper)

# %%
# Drop rows with >30% missing values
threshold = int(df_capped.shape[1] * 0.7)
df_clean = df_capped.dropna(thresh=threshold)

# Forward fill weather variables
df_clean[cols] = df_clean[cols].ffill()

# %%
country = "sudan"
df_clean.to_csv(f"../../dataset/{country}_clean.csv", index=False)

# %% [markdown]
# Time Series Analysis

# %%
# Convert Date column to datetime
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
# Set as index
df_clean.set_index('Date', inplace=True)

# %%
print(df_clean.index)
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2026-03-22', '2026-03-23', '2026-03-24', '2026-03-25',
#                '2026-03-26', '2026-03-27', '2026-03-28', '2026-03-29',
#                '2026-03-30', '2026-03-31'],
#               dtype='datetime64[us]', name='Date', length=4108, freq=None)

# %%
# Create monthly aggregates
monthly = df_clean.resample('ME').mean(numeric_only=True)

# Monthly precipitation (sum, not mean)
monthly_precip = df_clean.resample('ME')['PRECTOTCORR'].sum()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(monthly.index, monthly['T2M'])

# Annotate extremes
max_idx = monthly['T2M'].idxmax()
min_idx = monthly['T2M'].idxmin()

plt.scatter(max_idx, monthly.loc[max_idx,'T2M'], color='red')
plt.scatter(min_idx, monthly.loc[min_idx,'T2M'], color='blue')

plt.title("Monthly Average T2M")
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.show()

# %% [markdown]
# Comment: This code performs exploratory data analysis (EDA) on the Sudan climate dataset.
# It includes data cleaning steps such as handling missing values, capping outliers, and creating monthly aggregates.
# Finally, it visualizes the monthly average temperature (T2M) and highlights the maximum and minimum points.
#
# The Mpnthly average T2M plot shows the overall trend and seasonal patterns in temperature over time.
# The red point around 2024 indicates the month with the highest average temperature,
# while the blue pointaround early 2020 indicates the month with the lowest average temperature.
#
# overall this EDA reflects stable but seasonally driven temprature behaviour with requires requires detail analysis.

# %% [markdown]
# Correlation & Relationship Analysis

# %%
import seaborn as sns
numeric_df = df_clean.select_dtypes(include='number')
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Correlations:
#
#     1. T2M, T2M_MAX, T2M_MIN
#         Relationship: Strong Positive
#
#         Interpretation:
#         Temprature is mostly synchronized which shows that when the day is hotter, the night is also warm.
#
#     2. QV2M vs RH2M
#        Relationship: Strong Positive
#
#         Interpretation:
#         AS QV2M increases, RH2M also increases. which shows temprature fluctustion is not the only reason for RH2M increment.
#
#     3. RH2M  vs T2M_RANGE
#        Relationship: Strong Negative
#
#         Interpretation:
#         As days RH2M decreases, inversily T2M_RANGE increases significantly.

# %%
# T2M vs RH2M
plt.scatter(df_clean['T2M'], df_clean['RH2M'])
plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.show()

# %% [markdown]
# Relationship: This graph shows a weak negative correlation overall, especially as the temperature rises above 15°C.
#
# Interpretation: As the temprature increases the humidity lies almost the same range except at some points around 25-30C which shows there are some outliers.

# %%
# T2M_RANGE vs WS2M
df_clean['T2M_RANGE'] = df_clean['T2M_MAX'] - df_clean['T2M_MIN']

plt.scatter(df_clean['T2M_RANGE'], df_clean['WS2M'])
plt.xlabel('T2M_RANGE')
plt.ylabel('WS2M')
plt.show()

# %% [markdown]
# Relationship: Temprature and Wind speed has weak correlation.
#
# Interpretation: It shows that there is high variablity of windspeed at different temprature.

# %% [markdown]
# Distribution Analysis

# %%
plt.hist(df_clean['PRECTOTCORR'], bins=50)
plt.yscale('log')  # if skewed
plt.title("PRECTOTCORR Distribution")
plt.show()

# %% [markdown]
# Relationship: The histogram is right skewed
#
# Interpretation: The long bar at 0 indicates that most days has no rain.
#                 the right skewedness of the graph shows that mostly there is dry season in the country.

# %%
plt.scatter(
    df_clean['T2M'],
    df_clean['RH2M'],
    s=df_clean['PRECTOTCORR'] * 10,  # scale bubbles
    alpha=0.5
)

plt.xlabel('T2M')
plt.ylabel('RH2M')
plt.title('Bubble Chart')
plt.show()

# %% [markdown]
# Relationship: Negative coorelation as the bubbles slops downward.
#
# Interpretation: There is high humidity trend when the temprature is in between 25-30.
